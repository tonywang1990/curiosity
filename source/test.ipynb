# %%
from car import Car
from PIL import Image
import logging
logging.basicConfig(level=logging.INFO)


car = Car()
#car.get_target_list()
#car.test()
res = car.loop(args={'tgt_ids':[17, 0], 'tgt_key':'score'}, max_iter=100, debug=True)
ctrl = car.controllers['back_wheels']
ctrl.plot('back_wheels')
 


## TODO: change to only return one target
## TODO: use exp moving avg
## TODO: use PID, and save and plot tracking curves
# Out:
# INFO:car:camera frame rate: 30.0
# DEBUG "back_wheels.py": Set debug off
# DEBUG "TB6612.py": Set debug off
# DEBUG "TB6612.py": Set debug off
# DEBUG "PCA9685.py": Set debug off
# INFO:car:Camera: frame center (320.0, 240.0), target center (316.5, 237.5), error (-3.5, -82.5), update (0.13610073890629992, 3.2080891319399942)
# INFO:car:pan: 90, pan_change: 0.13610073890629992, tilt: 90, pan_change: 3.2080891319399942
# INFO:car:Backwheels: actual_size 296877, goal_size 92160.0, error 204717.0, speed 0
# INFO:car:FrontWheels: direction -2150, turn 90.1361007389063
# INFO:car:Camera: frame center (320.0, 240.0), target center (317.5, 238.5), error (-2.5, -81.5), update (0.07874252216562025, 3.1523589527697298)
# INFO:car:pan: 90.1361007389063, pan_change: 0.07874252216562025, tilt: 93.20808913194, pan_change: 3.1523589527697298
# INFO:car:Backwheels: actual_size 306081, goal_size 92160.0, error 213921.0, speed -100
# INFO:car:FrontWheels: direction -2226, turn 90.21484326107192
# ...

# %%
car = Car()
car.front_wheels.turn = 85.5

# %%
l = pan_ctrl.log['error'][:-50]
for i, v in enumerate(l):
    print(i, v)
# Out:
# 0 -31.0
# 1 -26.0
# 2 -22.5
# 3 -14.0
# 4 -15.0
# 5 -30.0
# 6 -116.5
# 7 -26.0
# 8 -14.0
# 9 -58.0
# 10 -90.5
# 11 -89.0
# 12 -109.5
# 13 -100.0
# 14 -85.5
# 15 -76.0
# 16 -67.0
# 17 -15.5
# 18 35.5
# 19 53.0
# 20 88.0
# 21 101.0
# 22 121.5
# 23 118.0
# 24 115.0
# 25 84.0
# 26 75.0
# 27 16.5
# 28 -14.5
# 29 -26.0
# 30 -63.5
# 31 -113.5
# 32 -113.5
# 33 -118.5
# 34 -118.5
# 35 -117.5
# 36 -56.0
# 37 -80.5
# 38 -12.0
# 39 46.5
# 40 55.0
# 41 97.5
# 42 124.0
# 43 120.0
# 44 121.0
# 45 120.0
# 46 101.0
# 47 88.0
# 48 23.0
# 49 3.5
# 50 -60.0
# 51 -85.5
# 52 -85.5
# 53 -123.0
# 54 -131.5
# 55 -138.0
# 56 -133.0
# 57 -119.0
# 58 -84.0
# 59 4.0
# 60 -7.0
# 61 55.0
# 62 107.0
# 63 133.0
# 64 138.0
# 65 138.0
# 66 141.0
# 67 139.0
# 68 110.5
# 69 78.5
# 70 26.0
# 71 -54.0
# 72 -60.0
# 73 -95.5
# 74 -128.0
# 75 -165.5
# 76 -154.5
# 77 -123.0
# 78 -113.5
# 79 -113.5
# 80 9.0
# 81 -8.0
# 82 37.0
# 83 101.0
# 84 108.0
# 85 126.5
# 86 120.0
# 87 126.5
# 88 112.5
# 89 110.5
# 90 40.0
# 91 37.0
# ...

# %%
display(Image.fromarray(res[1]))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
dic = {'t': 1}
print(dic.get('a', None))
# Out:
# None

# %%
max([1])
# Out:
# 1

# %%
from primitive import Context
context = Context()
context.camera_pan = 5
print(context)
# Out:
# {
#   "camera_pan": 5
# }
